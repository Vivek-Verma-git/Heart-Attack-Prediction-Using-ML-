# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import os
print(os.listdir())

import warnings
warnings.filterwarnings('ignore')
# Out:
# ['.config', 'drive', 'sample_data']

# %%
dataset = pd.read_csv("/content/drive/MyDrive/updated_heart_dataset.csv")

# %%
import pandas as pd

# Set options to display all rows and columns
pd.set_option("display.max_rows", None)  # Show all rows
pd.set_option("display.max_columns", None)  # Show all columns

# Now, display your dataset
dataset  # Assuming your dataset is stored in a variable called 'dataset'
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.describe(include='all')
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak  ...        thal  \
# count  303.000000  303.000000  303.000000  303.000000  ...  303.000000
# mean     0.528053  149.646865    0.326733    1.039604  ...    2.313531
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  303 non-null    int64
#  1   sex                  303 non-null    int64
#  2   cp                   303 non-null    int64
#  3   trestbps             303 non-null    int64
#  4   chol                 303 non-null    int64
#  5   fbs                  303 non-null    int64
#  6   restecg              303 non-null    int64
#  7   thalach              303 non-null    int64
#  8   exang                303 non-null    int64
#  9   oldpeak              303 non-null    float64
#  10  slope                303 non-null    int64
#  11  ca                   303 non-null    int64
#  12  thal                 303 non-null    int64
#  13  target               303 non-null    int64
#  14  left_hand_pain       303 non-null    int64
# ...

# %%
# List of column explanations
info = [
    "age: Continuous variable (years). Consider grouping into age brackets.",
    "sex: 1 = male, 0 = female",
    "cp: Chest pain type (1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic)",
    "trestbps: Resting blood pressure (mm Hg)",
    "chol: Serum cholesterol in mg/dl",
    "fbs: Fasting blood sugar > 120 mg/dl (1 = true, 0 = false)",
    "restecg: Resting electrocardiographic results (0: normal, 1: ST-T wave abnormality, 2: probable/definite left ventricular hypertrophy)",
    "thalach: Maximum heart rate achieved",
    "exang: Exercise-induced angina (1 = yes, 0 = no)",
    "oldpeak: ST depression induced by exercise relative to rest (continuous variable)",
    "slope: Slope of the peak exercise ST segment (1: upsloping, 2: flat, 3: downsloping)",
    "ca: Number of major vessels (0-3) colored by fluoroscopy",
    "thal: Thalassemia (3: normal, 6: fixed defect, 7: reversible defect)",
    "target: Target variable (0: no heart disease, 1: heart disease)",
    "left_hand_pain: Left hand pain (1 = Present, 0 = Absent)",
    "shortness_of_breath: Shortness of breath (1 = Present, 0 = Absent)",
    "fatigue: Fatigue (1 = Present, 0 = Absent)",
    "cold_sweats: Cold sweats (1 = Present, 0 = Absent)",
    "dizziness: Dizziness (1 = Present, 0 = Absent)",
    "sleep_disruption: Sleep disruption (1 = Present, 0 = Absent)",
    "swelling: Swelling (e.g., in legs or ankles) (1 = Present, 0 = Absent)"
]

# Print column information
for i in range(len(column)):
    print(f"{column[i]}: {info[i] if i < len(info) else 'No specific explanation available.'}")
# Out:
# d: age: Continuous variable (years). Consider grouping into age brackets.
# i: sex: 1 = male, 0 = female
# z: cp: Chest pain type (1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic)
# z: trestbps: Resting blood pressure (mm Hg)
# i: chol: Serum cholesterol in mg/dl
# n: fbs: Fasting blood sugar > 120 mg/dl (1 = true, 0 = false)
# e: restecg: Resting electrocardiographic results (0: normal, 1: ST-T wave abnormality, 2: probable/definite left ventricular hypertrophy)
# s: thalach: Maximum heart rate achieved
# s: exang: Exercise-induced angina (1 = yes, 0 = no)

# %%
dataset["target"].describe()
# Out:
# count    303.000000
# mean       0.544554
# std        0.498835
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
dataset["target"].unique()
# Out:
# array([1, 0])

# %%
print(dataset.corr()["target"].abs().sort_values(ascending=False))
# Out:
# target                 1.000000
# exang                  0.436757
# cp                     0.433798
# oldpeak                0.430696
# thalach                0.421741
# ca                     0.391724
# slope                  0.345877
# thal                   0.344029
# sex                    0.280937
# age                    0.225439
# trestbps               0.144931
# restecg                0.137230
# sleep_disruption       0.093424
# chol                   0.085239
# shortness_of_breath    0.079520
# swelling               0.072262
# jaw_pain               0.058297
# fatigue                0.035955
# cold_sweats            0.030170
# dizziness              0.029454
# fbs                    0.028046
# left_hand_pain         0.025695
# Name: target, dtype: float64

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Assuming dataset is loaded into the 'dataset' DataFrame

# List of binary columns
binary_columns = [
    "sex", "fbs", "exang", "left_hand_pain", "shortness_of_breath",
    "fatigue", "cold_sweats", "sleep_disruption", "swelling", "jaw_pain",
    "dizziness"
]

# Target column
target_column = "target"

# Perform Chi-squared test for each binary feature with the target variable
for column in binary_columns:
    # Create a contingency table
    contingency_table = pd.crosstab(dataset[column], dataset[target_column])

    # Perform Chi-squared test
    chi2_stat, p_val, dof, expected = chi2_contingency(contingency_table)

    # Output the result
    print(f"Chi-squared test for {column} and {target_column}:")
    print(f"Chi-squared statistic: {chi2_stat}")
    print(f"P-value: {p_val}\n")

    # Interpret the p-value
    if p_val < 0.05:
        print(f"**There is a significant association between {column} and {target_column}.**\n")
    else:
        print(f"There is no significant association between {column} and {target_column}.\n")
# Out:
# Chi-squared test for sex and target:
# Chi-squared statistic: 22.717227046576355
# P-value: 1.8767776216941503e-06
#
# **There is a significant association between sex and target.**
#
# Chi-squared test for fbs and target:
# Chi-squared statistic: 0.10627276301947715
# P-value: 0.7444281114149577
#
# There is no significant association between fbs and target.
#
# Chi-squared test for exang and target:
# Chi-squared statistic: 55.94454996665093
# P-value: 7.454409331235655e-14
#
# **There is a significant association between exang and target.**
#
# Chi-squared test for left_hand_pain and target:
# Chi-squared statistic: 0.08920089492886998
# P-value: 0.7651955207521768
#
# There is no significant association between left_hand_pain and target.
#
# Chi-squared test for shortness_of_breath and target:
# Chi-squared statistic: 1.581467247591538
# P-value: 0.20854947486874872
#
# There is no significant association between shortness_of_breath and target.
#
# ...

# %%
from sklearn.model_selection import train_test_split

predictors = dataset.drop("target",axis=1)
target = dataset["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (242, 21)

# %%
X_test.shape
# Out:
# (61, 21)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 83.61 %

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,Y_train)

Y_pred_nb = nb.predict(X_test)

# %%
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 83.61 %

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(X_train, Y_train)

Y_pred_svm = sv.predict(X_test)

# %%
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 83.61 %

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)

# %%
score_knn = round(accuracy_score(Y_pred_knn,Y_test)*100,2)

print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 67.21 %

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x

#print(max_accuracy)
#print(best_x)


dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)

# %%
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 78.69 %

# %%
from sklearn.ensemble import RandomForestClassifier

max_accuracy = 0


for x in range(2000):
    rf = RandomForestClassifier(random_state=x)
    rf.fit(X_train,Y_train)
    Y_pred_rf = rf.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x

#print(max_accuracy)
#print(best_x)

rf = RandomForestClassifier(random_state=best_x)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)

# %%
score_rf = round(accuracy_score(Y_pred_rf,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 93.44 %

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 83.61 %

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(11,activation='relu',input_dim=21))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,epochs=300)
# Out:
# Epoch 1/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4908 - loss: 143.4791
# Epoch 2/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4205 - loss: 150.0607
# Epoch 3/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4538 - loss: 129.5193
# Epoch 4/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4125 - loss: 128.3472
# Epoch 5/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4330 - loss: 111.6661
# Epoch 6/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4814 - loss: 92.4401
# Epoch 7/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4691 - loss: 82.4228
# Epoch 8/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4919 - loss: 70.2308
# Epoch 9/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4486 - loss: 65.7663
# Epoch 10/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4675 - loss: 53.1899
# Epoch 11/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5039 - loss: 40.2933
# Epoch 12/300
# ...

# %%
Y_pred_nn = model.predict(X_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
Y_pred_nn.shape
# Out:
# (61, 1)

# %%
rounded = [round(x[0]) for x in Y_pred_nn]

Y_pred_nn = rounded

# %%
score_nn = round(accuracy_score(Y_pred_nn,Y_test)*100,2)

print("The accuracy score achieved using Neural Network is: "+str(score_nn)+" %")

#Note: Accuracy of 85% can be achieved on the test set, by setting epochs=2000, and number of nodes = 11.
# Out:
# The accuracy score achieved using Neural Network is: 81.97 %

# %%
scores = [score_lr,score_nb,score_svm,score_knn,score_dt,score_rf,score_xgb,score_nn]
algorithms = ["Logistic Regression","Naive Bayes","Support Vector Machine","K-Nearest Neighbors","Decision Tree","Random Forest","XGBoost","Neural Network"]

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 83.61 %
# The accuracy score achieved using Naive Bayes is: 83.61 %
# The accuracy score achieved using Support Vector Machine is: 83.61 %
# The accuracy score achieved using K-Nearest Neighbors is: 67.21 %
# The accuracy score achieved using Decision Tree is: 78.69 %
# The accuracy score achieved using Random Forest is: 93.44 %
# The accuracy score achieved using XGBoost is: 83.61 %
# The accuracy score achieved using Neural Network is: 81.97 %

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(20,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

# Pass data as keyword arguments x and y
sns.barplot(x=algorithms, y=scores)
plt.show() # Add this line to display the plot

# %%
import joblib

# Save your trained model
joblib.dump(rf, '/content/model.pkl')
# Out:
# ['/content/model.pkl']

# %%
from google.colab import files

files.download('/content/model.pkl')

# %%
# First, install the graphviz package if not already installed
# !pip install graphviz

# Import the necessary library
from graphviz import Digraph

# Create a Digraph object
dot = Digraph(comment='Heart Attack Prediction Methodology')

# Add nodes (steps in the methodology)
dot.node('A', 'Data Collection')
dot.node('B', 'Data Preprocessing')
dot.node('C', 'Model Selection (Random Forest)')
dot.node('D', 'Model Training')
dot.node('E', 'Model Evaluation')
dot.node('F', 'User Interface (UI)')

# Add edges (showing the flow between steps)
dot.edge('A', 'B')
dot.edge('B', 'C')
dot.edge('C', 'D')
dot.edge('D', 'E')
dot.edge('E', 'F')

# Render and view the flow diagram
dot.render('/content/heart_attack_prediction_flow', format='png', view=True)
# Out:
# ...
# '/content/heart_attack_prediction_flow.png'

# %%
from google.colab import files

files.download('/content/heart_attack_prediction_flow')

# %%
# Install necessary libraries
# !pip install networkx matplotlib

# Import the required libraries
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes representing each step in the methodology
G.add_node('Data Collection')
G.add_node('Data Preprocessing')
G.add_node('Model Selection\n(Random Forest)')
G.add_node('Model Training')
G.add_node('Model Evaluation')
G.add_node('User Interface (UI)')

# Add directed edges between the nodes to represent the flow
G.add_edges_from([
    ('Data Collection', 'Data Preprocessing'),
    ('Data Preprocessing', 'Model Selection\n(Random Forest)'),
    ('Model Selection\n(Random Forest)', 'Model Training'),
    ('Model Training', 'Model Evaluation'),
    ('Model Evaluation', 'User Interface (UI)')
])

# Set up the position of the nodes
pos = {
    'Data Collection': (0, 1),
    'Data Preprocessing': (0, 0.5),
    'Model Selection\n(Random Forest)': (0, 0),
    'Model Training': (1, 1),
    'Model Evaluation': (1, 0.5),
    'User Interface (UI)': (1, 0),
}

# Draw the graph with customizations
plt.figure(figsize=(10, 5))
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='lightblue', font_size=10, font_weight='bold', arrows=True, arrowsize=20, edge_color='black')

# Show the plot
plt.title('Heart Attack Prediction Methodology Flow', fontsize=14)
plt.axis('off')
# Out:
# ...
# (-0.10500000000000001, 1.105, -0.10500000000000001, 1.105)
